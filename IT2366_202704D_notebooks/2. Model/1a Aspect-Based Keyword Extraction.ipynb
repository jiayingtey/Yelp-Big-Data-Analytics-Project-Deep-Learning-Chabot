# %% [markdown]
# ###Package Imports

# %%
pip install gensim==3.8.3
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached gensim-3.8.3-cp38-cp38-manylinux1_x86_64.whl (24.2 MB)
# ...
#   Using cached smart_open-5.2.1-py3-none-any.whl (58 kB)
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-64a7d89d-98f7-4e2f-b91a-5de386d78cfe/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.

# %%
pip install nltk
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached nltk-3.6.7-py3-none-any.whl (1.5 MB)
# ...
#   Using cached tqdm-4.62.3-py2.py3-none-any.whl (76 kB)
# ...
#   Using cached click-8.0.3-py3-none-any.whl (97 kB)
# ...
#   Using cached regex-2021.11.10-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (764 kB)
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-64a7d89d-98f7-4e2f-b91a-5de386d78cfe/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.

# %%
pip install keras
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached keras-2.7.0-py2.py3-none-any.whl (1.3 MB)
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-64a7d89d-98f7-4e2f-b91a-5de386d78cfe/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.

# %%
pip install tensorflow
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached tensorflow-2.7.0-cp38-cp38-manylinux2010_x86_64.whl (489.6 MB)
# ...
#   Using cached libclang-12.0.0-2-py2.py3-none-manylinux1_x86_64.whl (13.3 MB)
# ...
#   Using cached wrapt-1.13.3-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
# ...
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# ...
#   Using cached tensorflow_io_gcs_filesystem-0.23.1-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.1 MB)
# ...
#   Using cached flatbuffers-2.0-py2.py3-none-any.whl (26 kB)
# ...
#   Using cached termcolor-1.1.0-py3-none-any.whl
# ...
#   Using cached tensorflow_estimator-2.7.0-py2.py3-none-any.whl (463 kB)
# ...
#   Using cached tensorboard-2.7.0-py3-none-any.whl (5.8 MB)
# ...

# %%
pip install spacy
# Out:
# Python interpreter will be restarted.
# ...
#   Using cached spacy-3.2.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.2 MB)
# ...
#   Using cached murmurhash-1.0.6-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# ...
#   Using cached typer-0.4.0-py3-none-any.whl (27 kB)
# ...
#   Using cached cymem-2.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36 kB)
# ...
#   Using cached catalogue-2.0.6-py3-none-any.whl (17 kB)
# ...
#   Using cached langcodes-3.3.0-py3-none-any.whl (181 kB)
# ...
#   Using cached srsly-2.4.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (454 kB)
# ...
#   Using cached pathy-0.6.1-py3-none-any.whl (42 kB)
# ...
#   Using cached spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# ...
#   Using cached pydantic-1.8.2-cp38-cp38-manylinux2014_x86_64.whl (13.7 MB)
# ...
#   Using cached thinc-8.0.13-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (636 kB)
# ...
#   Using cached spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# ...

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0.tar.gz --no-deps
# Out:
# Python interpreter will be restarted.
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-3.2.0-py3-none-any.whl size=13900194 sha256=6df958558366a0a8bfb2f6145e7a59fd215e8aee5e38c6aa92a0e1e4298c120f
#   Stored in directory: /root/.cache/pip/wheels/dd/42/a5/bc03d010e897348c09e48307bbce5d5662d6dd5ab68762b2eb
# Successfully built en-core-web-sm
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.3.1 is available.
# You should consider upgrading via the '/local_disk0/.ephemeral_nfs/envs/pythonEnv-64a7d89d-98f7-4e2f-b91a-5de386d78cfe/bin/python -m pip install --upgrade pip' command.
# Python interpreter will be restarted.

# %%
# %sh

python -m spacy validate
# Out:
# 2022-01-13 16:48:55.643646: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-13 16:48:55.647969: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
#
# ⠙ Loading compatibility table...
# ⠹ Loading compatibility table...
# ⠸ Loading compatibility table...
# ✔ Loaded compatibility table
#
# ================= Installed pipeline packages (spaCy v3.2.1) =================
# ℹ spaCy installation:
# /local_disk0/.ephemeral_nfs/envs/pythonEnv-64a7d89d-98f7-4e2f-b91a-5de386d78cfe/lib/python3.8/site-packages/spacy
#
# NAME             SPACY            VERSION
# en_core_web_sm   >=3.2.0,<3.3.0   3.2.0   ✔

# %%
import pandas as pd
import random
import numpy as np
import nltk
import pandas as pd
import numpy as np
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models import Doc2Vec
from sklearn import utils
from sklearn.model_selection import train_test_split
from keras.preprocessing.sequence import pad_sequences
import gensim
from sklearn.linear_model import LogisticRegression
from gensim.models.doc2vec import TaggedDocument
from keras.preprocessing.text import Tokenizer
import re
import seaborn as sns
import matplotlib.pyplot as plt
from nltk import pos_tag
from nltk import RegexpParser

from keras.preprocessing import sequence, text
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.layers import Embedding, LSTM
from keras.layers import Conv1D, Flatten, MaxPooling1D
from tensorflow import keras
from keras import utils

from keras.preprocessing.text import Tokenizer


import itertools
import os


import numpy as np
import pandas as pd
import tensorflow as tf

from sklearn.preprocessing import LabelBinarizer, LabelEncoder
from sklearn.metrics import confusion_matrix

import nltk

from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Out[4]: True

# %%
import spacy
from spacy import displacy
nlp = spacy.load('en_core_web_sm')

# %%
# %%time

# read in a simple (small) English language model
nlp = spacy.load('en')

# another approach:
# import en_core_web_sm
# nlp = en_core_web_sm.load()

# %%
# %%time 

# read in a (large) convolutional neural network model
# this will only work after the CNN model is downloaded (~800MB)
# e.g. python -m spacy download en_core_web_lg
nlp = spacy.load('en_core_web_lg')

# %%
import os
import pandas as pd
#from sqlalchemy import create_engine
from IPython.core.display import display, HTML
from IPython.display import Image
from configparser import ConfigParser, ExtendedInterpolation

# %% [markdown]
# ## <a id='3'><h2 style="background-color:lightsalmon;border-radius:5px;text-align:center;padding:7px;color:white;"><font color="white">Methodology</h2></a>

# %% [markdown]
# This will be how I will be carrying out the whole process
# 1. <b>NLP using SpaCy:</b> Text Processing
# 2. <b><u>Aspect Keyword Extraction:</u></b> Predict Aspect Keywords from text (Text Chunking & Regrex Parser)
# 3. <b>Aspect Keyword Sentiment:</b> Predict Sentiment based on keywords (Vader Sentiment Model)
# 4. <b>Aspect-Based Category Prediction Model:</b> Prediction category based on keywords (BOW + DNN Model)
#
# <b>Note: In this notebook we will be looking at step 2 & 3.</b>

# %%
reviewsDF = (spark.read
  .option("inferSchema", True)
  .json("/FileStore/tables/Project_Data_Extract/dataset_reviews_cleaned_w_NLP.json"))
reviewsDF.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
spark.conf.set("spark.sql.execution.arrow.enabled", "false")
reviews_pdf=reviewsDF.toPandas()
reviews_pdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>business_id</th>
#       <th>cool</th>
#       <th>date</th>
#       <th>funny</th>
#       <th>month</th>
#       <th>stars</th>
#       <th>text</th>
#       <th>text_basic_cleaned</th>
#       <th>text_syntatics_cleaned</th>
#       <th>useful</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>YZs1gNSh_sN8JmN_nrpxeA</td>
#       <td>0</td>
#       <td>2019-01-10</td>
#       <td>0</td>
#       <td>1</td>
#       <td>5.0</td>
#       <td>One of my favorite BBQ places in town. The mea...</td>
#       <td>one of my favorite bbq places in town the meat...</td>
# ...

# %%
tipsDF = (spark.read
  .option("inferSchema", True)
  .json("/FileStore/tables/Project_Data_Extract/dataset_tips_cleaned_w_NLP.json"))
tips_pdf=tipsDF.toPandas()
tips_pdf.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## <a id='1'><h2 style="background-color:lightsalmon;border-radius:5px;text-align:center;padding:7px;color:white;"><font color="white">Aspect Keyword Extraction</h2></a>

# %%
import nltk
def prepareForNLP(text):
	sentences = nltk.sent_tokenize(text)
	sentences = [nltk.word_tokenize(sent) for sent in sentences]
	sentences = [nltk.pos_tag(sent) for sent in sentences]
	return sentences

        
def chunk_text(sentence):
    #print(sentence)
    s=[]
    sentence=prepareForNLP(sentence)
    for sentence in sentence:
        chunkToExtract =r"""
        NP: {<ADJ><NN>+}
            {<NN><VBD><VBG>+}
            {<RB><VBG>+<RB>}
            {<RB>+<VBD>}
            {<RB>+<JJ>}
            {<NN>+<JJ>?<NN>}
            {<JJ>+<VBN>}
            {<JJ>+<NN>}
            {<MD><VB>}
            {<NN>?<VBD>+<JJ>}
            {<VB>?<JJ>+<NN>}
            {<VB>?<JJ>?<JJS>+<NN>}
        """
        
        #'''NP: {<VB>?<JJ>?<JJS>+<NN>}'''
        parser = nltk.RegexpParser(chunkToExtract)
        result = parser.parse(sentence)
        
     
        for subtree in result.subtrees():
            if subtree.label() == 'NP':
                t = subtree
                t = ' '.join(word for word, pos in t.leaves())
                s.append(t)
        return s
    
print(chunk_text('place big fatty star quality service pricered bean soup bigtime delishsamish wonderful small place home'))
# Out:
# ['place big fatty', 'star quality service', 'pricered bean', 'soup bigtime delishsamish wonderful', 'place home']

# %%
from pyspark.sql.types import *

# Auxiliar functions
def equivalent_type(f):
    if f == 'datetime64[ns]': return TimestampType()
    elif f == 'int64': return LongType()
    elif f == 'int32': return IntegerType()
    elif f == 'float64': return FloatType()
    else: return StringType()

def define_structure(string, format_type):
    try: typo = equivalent_type(format_type)
    except: typo = StringType()
    return StructField(string, typo)

# Given pandas dataframe, it will return a spark's dataframe.
def pandas_to_spark(pandas_df):
    columns = list(pandas_df.columns)
    types = list(pandas_df.dtypes)
    struct_list = []
    for column, typo in zip(columns, types): 
      struct_list.append(define_structure(column, typo))
    p_schema = StructType(struct_list)
    return sqlContext.createDataFrame(pandas_df, p_schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
reviews_pdf1=reviews_pdf.head(581328)
reviews_pdf1['Aspect Keywords']=reviews_pdf1['text_syntatics_cleaned'].apply(chunk_text)
DF=pandas_to_spark(reviews_pdf1) 
DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment1.json")
# Out:
# <command-421228694324390>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_pdf1['Aspect Keywords']=reviews_pdf1['text_syntatics_cleaned'].apply(chunk_text)

# %%
reviews_pdf2=reviews_pdf.iloc[581328:]
reviews_pdf2['Aspect Keywords']=reviews_pdf2['text_syntatics_cleaned'].apply(chunk_text)
DF=pandas_to_spark(reviews_pdf2) 
DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment2.json")
# Out:
# <command-4229277534970514>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_pdf2['Aspect Keywords']=reviews_pdf2['text_syntatics_cleaned'].apply(chunk_text)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-4229277534970514> in <module>
#       1 reviews_pdf2['Aspect Keywords']=reviews_pdf2['text_syntatics_cleaned'].apply(chunk_text)
# ----> 2 DF=pandas_to_spark(reviews_pdf2)
#       3 DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment2.json")
#
# NameError: name 'pandas_to_spark' is not defined

# %%
DF=pandas_to_spark(reviews_pdf2) 
DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment2.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
tips_pdf['Aspect Keywords']=reviews_pdf['text_syntatics_cleaned'].apply(chunk_text)
tipsDF=spark.createDataFrame(tips_pdf) 
tipsDF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/tips_aspect_keywordsentiment.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## <a id='2'><h2 style="background-color:lightsalmon;border-radius:5px;text-align:center;padding:7px;color:white;"><font color="white">Aspect Keyword Sentiment Prediction</h2></a>

# %%
DF = (spark.read
      .option("inferSchema", True).json("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment1.json"))
reviews_pdf1=DF.toPandas()
DF = (spark.read
      .option("inferSchema", True).json("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment2.json"))
reviews_pdf2=DF.toPandas()
reviews_pdf=pd.concat([reviews_pdf1,reviews_pdf2])
reviews_pdf.drop(['text','text_basic_cleaned'],axis=1,inplace=True)
reviews_pdf.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Aspect Keywords</th>
#       <th>business_id</th>
#       <th>cool</th>
#       <th>date</th>
#       <th>funny</th>
#       <th>month</th>
#       <th>stars</th>
#       <th>text_syntatics_cleaned</th>
#       <th>useful</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[barbeque place town meat side fantastic doe, ...</td>
#       <td>YZs1gNSh_sN8JmN_nrpxeA</td>
#       <td>0</td>
#       <td>2019-01-10</td>
#       <td>0</td>
#       <td>1</td>
#       <td>5.0</td>
#       <td>one favorite barbeque place town meat side fan...</td>
#       <td>0</td>
#     </tr>
#     <tr>
# ...

# %%
reviews_pdf.isnull().sum()
# Out:
# Out[63]: Aspect Keywords           227
# business_id                 0
# cool                        0
# date                        0
# funny                       0
# month                       0
# stars                       0
# text_syntatics_cleaned      0
# useful                      0
# dtype: int64

# %%
reviews_pdf.dropna(axis=0,inplace=True)
reviews_pdf.isnull().sum()
# Out:
# Out[64]: Aspect Keywords           0
# business_id               0
# cool                      0
# date                      0
# funny                     0
# month                     0
# stars                     0
# text_syntatics_cleaned    0
# useful                    0
# dtype: int64

# %%
DF = (spark.read
      .option("inferSchema", True).json("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/tips_aspect_keywordsentiment.json"))
tips_pdf=DF.toPandas()
tips_pdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Aspect Keywords</th>
#       <th>business_id</th>
#       <th>compliment_count</th>
#       <th>date</th>
#       <th>text</th>
#       <th>text_basic_cleaned</th>
#       <th>text_syntatics_cleaned</th>
#       <th>user_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[barbeque place town meat side fantastic doe, ...</td>
#       <td>ENwBByjpoa5Gg7tKgxqwLg</td>
#       <td>0</td>
#       <td>2011-07-22</td>
#       <td>Carne asada chips...</td>
#       <td>carne asada chips</td>
#       <td>carne asada chip</td>
#       <td>WCjg0jdHXMlwbqS9tZUx8Q</td>
#     </tr>
#     <tr>
# ...

# %%
tips_pdf.dropna(axis=0,inplace=True)
tips_pdf.isnull().sum()
# Out:
# Out[10]: Aspect Keywords           0
# business_id               0
# compliment_count          0
# date                      0
# text                      0
# text_basic_cleaned        0
# text_syntatics_cleaned    0
# user_id                   0
# dtype: int64

# %%
reviews_pdf['Aspect Keywords'].iloc[:100][13]
# Out:
# Out[40]: '[kelsey melody, service friend, free tuesday]'

# %%
def get_sentiment(text):
    s=[]
    text=text.strip('][').split(', ')
    for text in text:
        #print(text)
        score=sid.polarity_scores(text)['compound']
        if score>0:
            s.append('positive')
        elif score==0:
            s.append('neutral')
        elif score<0:
            s.append('negative')   
    return s

# %%
from pyspark.sql.types import *

# Auxiliar functions
def equivalent_type(f):
    if f == 'datetime64[ns]': return TimestampType()
    elif f == 'int64': return LongType()
    elif f == 'int32': return IntegerType()
    elif f == 'float64': return FloatType()
    else: return StringType()

def define_structure(string, format_type):
    try: typo = equivalent_type(format_type)
    except: typo = StringType()
    return StructField(string, typo)

# Given pandas dataframe, it will return a spark's dataframe.
def pandas_to_spark(pandas_df):
    columns = list(pandas_df.columns)
    types = list(pandas_df.dtypes)
    struct_list = []
    for column, typo in zip(columns, types): 
      struct_list.append(define_structure(column, typo))
    p_schema = StructType(struct_list)
    return sqlContext.createDataFrame(pandas_df, p_schema)
#DF=pandas_to_spark(tips_pdf) 
#DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_sentiment.json")

# %%
reviews_pdf['Aspect Sentiment']=reviews_pdf['Aspect Keywords'].apply(get_sentiment)
DF=pandas_to_spark(reviews_pdf) 
DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment.json")
# Out:
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:300: UserWarning: createDataFrame attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   Expected bytes, got a 'list' object
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
#   warnings.warn(msg)

# %%
def get_sentiment2(text):
    s=[]
    for text in text:
        #print(text)
        score=sid.polarity_scores(text)['compound']
        if score>0:
            s.append('positive')
        elif score==0:
            s.append('neutral')
        elif score<0:
            s.append('negative')   
    return s

# %%
tips_pdf['Aspect Sentiment']=tips_pdf['Aspect Keywords'].apply(get_sentiment2)

# %%
#tips_pdf['Aspect Sentiment']=tips_pdf['Aspect Keywords'].apply(get_sentiment2)
DF=pandas_to_spark(tips_pdf) 
DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/tips_aspect_keywordsentiment.json")
# Out:
# /databricks/spark/python/pyspark/sql/pandas/conversion.py:300: UserWarning: createDataFrame attempted Arrow optimization because 'spark.sql.execution.arrow.pyspark.enabled' is set to true; however, failed by the reason below:
#   Expected bytes, got a 'numpy.ndarray' object
# Attempting non-optimization as 'spark.sql.execution.arrow.pyspark.fallback.enabled' is set to true.
#   warnings.warn(msg)
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
tips_pdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <command-4229277534970570> in <module>
# ----> 1 tips_pdf
#
# NameError: name 'tips_pdf' is not defined

# %%
from pyspark.sql import SparkSession
#Create PySpark SparkSession
spark = SparkSession.builder \
    .master("local[1]") \
    .appName("SparkByExamples.com") \
    .getOrCreate()
#Create PySpark DataFrame from Pandas
DF=spark.createDataFrame(tips_pdf) 
DF.coalesce(1).write.mode('overwrite').format('json').save("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/tips_aspect_keywordsentiment.json")

# %%
DF = (spark.read
      .option("inferSchema", True).json("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/reviews_aspect_keywordsentiment.json"))
reviews_pdf=DF.toPandas()
reviews_pdf
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# org.json4s.package$MappingException: No usable value for execution_count
# Did not find value which can be converted into int
# 	at org.json4s.reflect.package$.fail(package.scala:95)
# 	at org.json4s.Extraction$ClassInstanceBuilder.org$json4s$Extraction$ClassInstanceBuilder$$buildCtorArg(Extraction.scala:599)
# 	at org.json4s.Extraction$ClassInstanceBuilder$$anonfun$3.applyOrElse(Extraction.scala:623)
# 	at org.json4s.Extraction$ClassInstanceBuilder$$anonfun$3.applyOrElse(Extraction.scala:621)
# 	at scala.PartialFunction.$anonfun$runWith$1$adapted(PartialFunction.scala:145)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# ...

# %%
DF = (spark.read
      .option("inferSchema", True).json("/FileStore/tables/Project_Data_Extract/Aspect_Dashboard/tips_aspect_keywordsentiment.json"))
tips_pdf=DF.toPandas()
tips_pdf
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Aspect Keywords</th>
#       <th>Aspect Sentiment</th>
#       <th>business_id</th>
#       <th>compliment_count</th>
#       <th>date</th>
#       <th>text</th>
#       <th>text_basic_cleaned</th>
#       <th>text_syntatics_cleaned</th>
#       <th>user_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>[barbeque place town meat side fantastic doe, ...</td>
#       <td>[positive, neutral, positive]</td>
#       <td>ENwBByjpoa5Gg7tKgxqwLg</td>
#       <td>0</td>
#       <td>2011-07-22</td>
#       <td>Carne asada chips...</td>
#       <td>carne asada chips</td>
# ...
